# %%
from validate import validate

# %%
INSTANCE = "instances/14.in"
PATH     = ["IXG", "EWQ", "MCY", "MER", "LKS", "OFE", "JEI", "PNS", "CWL", "JRO", "JPW", "PXB", "CFH", "QEM", "JDF", "JOK", "GIT", "IJS", "KPC", "HXV", "AZZ", "EPH", "GZG", "KEU", "SRB", "GZZ", "LYR", "PTG", "GTW", "QCY", "EJY", "IPC", "DQK", "OYJ", "EAJ", "CNY", "FGK", "KJN", "KQO", "DZU", "KUA", "USH", "JSN", "BCJ", "GUO", "JRF", "SSN", "HKP", "IAV", "KEV", "JFR", "IMH", "RTP", "SGD", "RLV", "EVS", "PWL", "MTA", "UDG", "ZHK", "UVX", "IPU", "MYJ", "YDC", "UFE", "NGK", "ODX", "DLU", "IZC", "JVE", "JSE", "QNQ", "BOW", "IZW", "NNS", "SJH", "SZB", "ITG", "ORA", "VQA", "FQX", "HDB", "GQV", "GCZ", "QYJ", "ZZV", "OOW", "PQK", "RUB", "ILP", "FKP", "QTS", "WGF", "HOH", "FPG", "HMF", "OQQ", "KBC", "YAF", "RUR", "WLK", "IJJ", "LMA", "CEA", "IFX", "EXL", "JTI", "EKJ", "BPO", "BNB", "OYM", "RDO", "DYS", "AGQ", "JQA", "AKF", "GXR", "AOL", "CFT", "DBP", "HFT", "SIQ", "OXF", "CEF", "FBV", "CCK", "DEI", "AOB", "AUQ", "AZP", "KII", "CDN", "DWY", "HHA", "DAX", "PMQ", "SOM", "QTT", "FES", "AAJ", "XJK", "GSD", "CKL", "HYF", "HXK", "AAL", "FLC", "BFF", "APY", "QQE", "PSK", "GAL", "OST", "DRK", "BRR", "FSE", "FSO", "BAH", "SRE", "JNH", "MMT", "OON", "XDS", "XIH", "QQM", "QLD", "XMU", "IVF", "RGA", "NZZ", "YAH", "ZPD", "VMZ", "SWR", "END", "OUO", "NWX", "SJX", "ZTD", "HHR", "MIZ", "IES", "WZV", "MWZ", "PAB", "LXM", "EBK", "QHL", "VMP", "QSS", "HLT", "NNJ", "WEN", "YDZ", "IKW", "DMI", "FXG", "JWW", "MXD", "PPL", "HKT", "MCB", "MMR", "TVT", "DOB", "SYY", "QSX", "KXF", "OEX", "SDF", "PGB", "TPF", "ZBA", "FDC", "OXB", "FON", "RDM", "ONX", "ZYZ", "ZOS", "NHX", "ZLA", "ULV", "TNR", "NAW", "MFF", "IER", "TOG", "JTW", "TKN", "VTF", "ZAW", "LWD", "EDF", "FIC", "VZA", "YFC", "DUB", "PMI", "NRF", "FGX", "UPE", "NXW", "WCQ", "JAK", "YHQ", "QVV", "ZGD", "EXG", "SLF", "FMC", "THL", "ZIT", "OGN", "RLF", "GIU", "WNQ", "QPR", "XDP", "JKA", "EKB", "XTR", "YLV", "QJO", "PZF", "IBE", "RZZ", "HIM", "VRY", "TKP", "MQW", "LCC", "QID", "MXN", "EVD", "WEC", "TIL", "OUL", "ZTM", "EWS", "NVF", "KXT", "XGR", "WCY", "VRH", "ZAH", "HVE", "WUC", "OXU", "KDT", "XJQ", "YBJ", "WBK", "UIE", "XZU", "ZUJ", "YZU", "SJO", "SVV", "ZPQ", "IXG"]

validate(INSTANCE, PATH)
# Out:
# ...
#   ✅  VALID   —   total cost = 114,378
# ...
#
#   Day   From → To     Area                        Cost
#   ----------------------------------------------------------------
#     1    IXG → EWQ    eetnsjplyb                   498  ✓
#     2    EWQ → MCY    nbfpeatecz                   267  ✓
#     3    MCY → MER    ndfpfbszpf                   107  ✓
#     4    MER → LKS    mstieuioiz                   110  ✓
#     5    LKS → OFE    otymrkfeql                   225  ✓
#     6    OFE → JEI    jytqvaiyev                   134  ✓
#     7    JEI → PNS    qmepuwamrl                   188  ✓
#     8    PNS → CWL    cnguretvzb                   159  ✓
#     9    CWL → JRO    kgsrawnpfv                    68  ✓
#    10    JRO → JPW    kcvnojawhh                   206  ✓
#    11    JPW → PXB    qunayoaiwz                   130  ✓
#    12    PXB → CFH    cfgsungypa                   283  ✓
#    13    CFH → QEM    qwvqeharkz                    56  ✓
# ...
